# %% [markdown]
# # Introduction to Graph Theory & Network Science
#
# ## Appendix: Solutions

# %% [markdown]
# # Modelling

# %%
for (u,v,w) in PG.edges(data=True):
    if w['PASSENGERS'] == p90_max and w['YEAR'] == 1990:
        print(u, '->', v)
# Out:
# LAX -> HNL

# %%
for (u,v,w) in PG.edges(data=True):
    if w['PASSENGERS'] == p15_max and w['YEAR'] == 2015:
        print(u, '->', v)
# Out:
# LAX -> SFO

# %%
passengers[(passengers['ORIGIN'] == 'LAX') & (passengers['DEST'] == 'HNL')].plot('YEAR', 'PASSENGERS')
passengers[(passengers['ORIGIN'] == 'LAX') & (passengers['DEST'] == 'SFO')].plot('YEAR', 'PASSENGERS')
